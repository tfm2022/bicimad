# %%
import json, requests
import pandas as pd

# %%
api_key = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJncGF1bGlub0B1Y20uZXMiLCJqdGkiOiI1ZjNhOGEyNC0zNWU5LTQ2OWQtODMxZC05NWM1MjczYzIzZDciLCJpc3MiOiJBRU1FVCIsImlhdCI6MTY1ODYwNTU1NywidXNlcklkIjoiNWYzYThhMjQtMzVlOS00NjlkLTgzMWQtOTVjNTI3M2MyM2Q3Iiwicm9sZSI6IiJ9.3tFdHDB4hYOyOZIyLwCudFnE3gRz-GZl5qWhyRGZ8dU'
response1 = requests.get('https://opendata.aemet.es/opendata/api/prediccion/especifica/municipio/horaria/28079/', headers={'api_key': api_key})
text = response1.text
data1 = json.loads(text)['datos']

# %%
data2[0]['prediccion']['dia']
# Out:
# [{'estadoCielo': [{'value': '11', 'periodo': '08', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '09', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '10', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '11', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '12', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '13', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '14', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '15', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '16', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '17', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '18', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '19', 'descripcion': 'Despejado'},
#    {'value': '11', 'periodo': '20', 'descripcion': 'Despejado'},
#    {'value': '12', 'periodo': '21', 'descripcion': 'Poco nuboso'},
# ...
