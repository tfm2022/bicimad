# %%
import json, requests

# %%
'''Login: Obtener accessToken'''

XClientId = 'c0c8cf02-e18b-4d9e-9af6-23ce93374c93'
passKey = '0676E16E4BE099A19D550C790D54CF9C4868156FEF13AA1389DA18A3DA5A85E7DD21632FCB75DF85AA623919697E4FBF823538E71B4105671A02865167901077'
response1 = requests.get('https://openapi.emtmadrid.es/v1/mobilitylabs/user/login/', headers={'X-ClientId': XClientId, 'passKey': passKey})
text = response1.text
data1 = json.loads(text)
accessToken = data1['data'][0]['accessToken']

# %%
response2 = requests.get('https://openapi.emtmadrid.es/v1/transport/bicimad/stations/', headers={'accessToken': accessToken})
text = response2.text
data2 = json.loads(text)['data']
data2 = pd.DataFrame(data2)
# Out:
#    id                    name  light number  \
# 0   1   1a - Puerta del Sol A      0     1a
# 1   2   1b - Puerta del Sol B      2     1b
# 2   3         2 - Miguel Moya      2      2
# 3   4  3 - Plaza Conde Suchil      2      3
# 4   5            4 - Malasaña      0      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count  \
# 0           30           7          21                   0
# 1           30          13          16                   0
# 2           24          11          12                   0
# 3           18           8          10                   0
# 4           24           3          19                   0
#
#                                             geometry
# 0  {'type': 'Point', 'coordinates': [-3.7018341, ...
# 1  {'type': 'Point', 'coordinates': [-3.701602938...
# 2  {'type': 'Point', 'coordinates': [-3.7058415, ...
# 3  {'type': 'Point', 'coordinates': [-3.7069171, ...
# 4  {'type': 'Point', 'coordinates': [-3.7025875, ...
