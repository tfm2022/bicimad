# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd 
import webbrowser
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
app = Nominatim(user_agent="tycgis")

# %%
madrid_map = folium.Map(location=[40.41831, -3.70275], zoom_start=12)

# %%
meteo_stations = pd.read_excel("data/stations/Estaciones_control_datos_meteorologicos.xls")
bicimad_stations = pd.read_excel("data/stations/bases_bicimad.xls")

# %%
latitudes_meteo = meteo_stations['LATITUD'].tolist()
longitudes_meteo = meteo_stations['LONGITUD'].tolist()
etiquetas_meteo = meteo_stations['ESTACIÓN'].tolist()

latitudes_bicimad = bicimad_stations['Latitud'].tolist()
longitudes_bicimad = bicimad_stations['Longitud'].tolist()
etiquetas_bicimad = bicimad_stations['Número'].tolist()

# %%
locations_meteo = folium.plugins.MarkerCluster().add_to(madrid_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lon, label in zip(latitudes_meteo,longitudes_meteo,etiquetas_meteo):
        folium.Marker(
        location=[lat, lon],
        icon=folium.Icon(color='red',icon="cloud", prefix='fa'),
        popup=label,
        ).add_to(locations_meteo)

locations_bicimad = folium.plugins.MarkerCluster().add_to(madrid_map)

for lat, lon, label in zip(latitudes_bicimad,longitudes_bicimad,etiquetas_bicimad):
        folium.Marker(
        location=[lat, lon],
        icon=folium.Icon(color='blue',icon="bicycle", prefix='fa'),
        popup=label,
        ).add_to(locations_bicimad)

# %%
madrid_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_479adbeb635c9483c1db7c4353af24a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_479adbeb635c9483c1db7c4353af24a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_479adbeb635c9483c1db7c4353af24a0 = L.map(
#                 &quot;map_479adbeb635c9483c1db7c4353af24a0&quot;,
#                 {
#                     center: [40.41831, -3.70275],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af0e256246cb3b792ac33633683b0c69 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_479adbeb635c9483c1db7c4353af24a0);
#
#
#             var marker_cluster_e3239e45c1a119736563eb42f6d4fe55 = L.markerClusterGroup(
#                 {}
#             );
#             map_479adbeb635c9483c1db7c4353af24a0.addLayer(marker_cluster_e3239e45c1a119736563eb42f6d4fe55);
#
#
#             var marker_22409239318d9e8f1901e4f8bb885ad3 = L.marker(
#                 [40.4238823, -3.7122567],
#                 {}
#             ).addTo(marker_cluster_e3239e45c1a119736563eb42f6d4fe55);
#
#
#             var icon_19d7de873bafdfc3dcd22ca9b21cf6a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_22409239318d9e8f1901e4f8bb885ad3.setIcon(icon_19d7de873bafdfc3dcd22ca9b21cf6a3);
#
#
#         var popup_f1b778f00d7b8733fa78e6a0c4ed52e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4cf5d525b8ed5e294a242fb4035fc02c = $(`&lt;div id=&quot;html_4cf5d525b8ed5e294a242fb4035fc02c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plaza España&lt;/div&gt;`)[0];
#             popup_f1b778f00d7b8733fa78e6a0c4ed52e7.setContent(html_4cf5d525b8ed5e294a242fb4035fc02c);
#
#
#         marker_22409239318d9e8f1901e4f8bb885ad3.bindPopup(popup_f1b778f00d7b8733fa78e6a0c4ed52e7)
#         ;
#
#
#
#
#             var marker_a23c03757dccedc474af2f06e8ce35c6 = L.marker(
#                 [40.4215533, -3.6823158],
#                 {}
#             ).addTo(marker_cluster_e3239e45c1a119736563eb42f6d4fe55);
#
#
#             var icon_3ccadc7341d2663a15a0bcd4ce8a7a55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a23c03757dccedc474af2f06e8ce35c6.setIcon(icon_3ccadc7341d2663a15a0bcd4ce8a7a55);
#
#
#         var popup_5f9ab5e43e105b00398c18ded7ba1358 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_71b3bc14c434627c12ebe0cb37103d2a = $(`&lt;div id=&quot;html_71b3bc14c434627c12ebe0cb37103d2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Escuelas Aguirre&lt;/div&gt;`)[0];
#             popup_5f9ab5e43e105b00398c18ded7ba1358.setContent(html_71b3bc14c434627c12ebe0cb37103d2a);
#
#
#         marker_a23c03757dccedc474af2f06e8ce35c6.bindPopup(popup_5f9ab5e43e105b00398c18ded7ba1358)
#         ;
#
#
#
#
#             var marker_8aa016f32c5af603399c77aa8373e691 = L.marker(
#                 [40.4400457, -3.6392422],
#                 {}
#             ).addTo(marker_cluster_e3239e45c1a119736563eb42f6d4fe55);
#
#
#             var icon_097ed63e36fb48322128ac2db04f68af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8aa016f32c5af603399c77aa8373e691.setIcon(icon_097ed63e36fb48322128ac2db04f68af);
#
#
#         var popup_fe23248386442a8e7d52bc1b57b2bd21 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5e1802ff06c1415c862b5259e8dfb81c = $(`&lt;div id=&quot;html_5e1802ff06c1415c862b5259e8dfb81c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arturo Soria&lt;/div&gt;`)[0];
#             popup_fe23248386442a8e7d52bc1b57b2bd21.setContent(html_5e1802ff06c1415c862b5259e8dfb81c);
#
#
#         marker_8aa016f32c5af603399c77aa8373e691.bin
