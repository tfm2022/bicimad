# %%
import pandas as pd
import numpy as np
import time
import datetime

df = pd.read_csv('../../data/DataFrame_Final_Cierre_FullFecha.csv', parse_dates=['FECHA'])

# %%
test=df.groupby(by=['TEMPORADA', 'TEMPORADA_NUM']).count()
test
# Out:
#                          ESTACION     ANIO      MES      DIA     HORA  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1               1031040  1031040  1031040  1031040  1031040
# OTONO     4                790464   790464   790464   790464   790464
# PRIMAVERA 2                781872   781872   781872   781872   781872
# VERANO    3                790464   790464   790464   790464   790464
#
#                            FECHA  DIA_SEMANA    AM_PM  Es_Festivo  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1              1031040     1031040  1031040     1031040
# OTONO     4               790464      790464   790464      790464
# PRIMAVERA 2               781872      781872   781872      781872
# VERANO    3               790464      790464   790464      790464
#
#                          Es_FinSemana  TEMPERATURA   VIENTO  PRESION  HUMEDAD  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1                   1031040      1031040  1031040  1031040  1031040
# ...

# %%
df['TEMPORADA_NUM'] = 0

# %%
df
# Out:
#          ESTACION  ANIO  MES  DIA  HORA               FECHA  DIA_SEMANA AM_PM  \
# 0               6  2018    1    1     0 2018-01-01 00:00:00           2    AM
# 1               6  2018    1    1     1 2018-01-01 01:00:00           2    AM
# 2               6  2018    1    1     2 2018-01-01 02:00:00           2    AM
# 3               6  2018    1    1     3 2018-01-01 03:00:00           2    AM
# 4               6  2018    1    1     4 2018-01-01 04:00:00           2    AM
# ...           ...   ...  ...  ...   ...                 ...         ...   ...
# 3393835       198  2020    2   29    19 2020-02-29 19:00:00           7    PM
# 3393836       198  2020    2   29    20 2020-02-29 20:00:00           7    PM
# 3393837       198  2020    2   29    21 2020-02-29 21:00:00           7    PM
# 3393838       198  2020    2   29    22 2020-02-29 22:00:00           7    PM
# 3393839       198  2020    2   29    23 2020-02-29 23:00:00           7    PM
#
# ...

# %%
df[df['TEMPORADA']=='INVIERNO']
# Out:
#          ESTACION  ANIO  MES  DIA  HORA               FECHA  DIA_SEMANA AM_PM  \
# 0               6  2018    1    1     0 2018-01-01 00:00:00           2    AM
# 1               6  2018    1    1     1 2018-01-01 01:00:00           2    AM
# 2               6  2018    1    1     2 2018-01-01 02:00:00           2    AM
# 3               6  2018    1    1     3 2018-01-01 03:00:00           2    AM
# 4               6  2018    1    1     4 2018-01-01 04:00:00           2    AM
# ...           ...   ...  ...  ...   ...                 ...         ...   ...
# 3393835       198  2020    2   29    19 2020-02-29 19:00:00           7    PM
# 3393836       198  2020    2   29    20 2020-02-29 20:00:00           7    PM
# 3393837       198  2020    2   29    21 2020-02-29 21:00:00           7    PM
# 3393838       198  2020    2   29    22 2020-02-29 22:00:00           7    PM
# 3393839       198  2020    2   29    23 2020-02-29 23:00:00           7    PM
#
# ...

# %%
df.loc[df['TEMPORADA']=='INVIERNO', 'TEMPORADA_NUM'] = 1
df.loc[df['TEMPORADA']=='PRIMAVERA', 'TEMPORADA_NUM'] = 2
df.loc[df['TEMPORADA']=='VERANO', 'TEMPORADA_NUM'] = 3
df.loc[df['TEMPORADA']=='OTONO', 'TEMPORADA_NUM'] = 4
df
# Out:
#          ESTACION  ANIO  MES  DIA  HORA               FECHA  DIA_SEMANA AM_PM  \
# 0               6  2018    1    1     0 2018-01-01 00:00:00           2    AM
# 1               6  2018    1    1     1 2018-01-01 01:00:00           2    AM
# 2               6  2018    1    1     2 2018-01-01 02:00:00           2    AM
# 3               6  2018    1    1     3 2018-01-01 03:00:00           2    AM
# 4               6  2018    1    1     4 2018-01-01 04:00:00           2    AM
# ...           ...   ...  ...  ...   ...                 ...         ...   ...
# 3393835       198  2020    2   29    19 2020-02-29 19:00:00           7    PM
# 3393836       198  2020    2   29    20 2020-02-29 20:00:00           7    PM
# 3393837       198  2020    2   29    21 2020-02-29 21:00:00           7    PM
# 3393838       198  2020    2   29    22 2020-02-29 22:00:00           7    PM
# 3393839       198  2020    2   29    23 2020-02-29 23:00:00           7    PM
#
# ...

# %%
test=df.groupby(by=['TEMPORADA', 'TEMPORADA_NUM']).count()
test
# Out:
#                          ESTACION     ANIO      MES      DIA     HORA  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1               1031040  1031040  1031040  1031040  1031040
# OTONO     4                790464   790464   790464   790464   790464
# PRIMAVERA 2                781872   781872   781872   781872   781872
# VERANO    3                790464   790464   790464   790464   790464
#
#                            FECHA  DIA_SEMANA    AM_PM  Es_Festivo  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1              1031040     1031040  1031040     1031040
# OTONO     4               790464      790464   790464      790464
# PRIMAVERA 2               781872      781872   781872      781872
# VERANO    3               790464      790464   790464      790464
#
#                          Es_FinSemana  TEMPERATURA   VIENTO  PRESION  HUMEDAD  \
# TEMPORADA TEMPORADA_NUM
# INVIERNO  1                   1031040      1031040  1031040  1031040  1031040
# ...

# %%
# REORDENAMIENTO DE COLUMNAS PREVIO A EXPORT

data_final_cierre = df[['ESTACION', 'ANIO', 'MES', 'DIA', 'HORA', 'FECHA', 'DIA_SEMANA', 'AM_PM', 'TEMPORADA', 'TEMPORADA_NUM', 'Es_Festivo', 'Es_FinSemana', 
                    'TEMPERATURA', 'VIENTO', 'PRESION', 'HUMEDAD', 'PRECIPITACION_1h', 'PRECIPITACION_3h', 'DESC_TIEMPO', 
                    'DESC_TIEMPO_detalle', 'DEMANDA']]
data_final_cierre
# Out:
#          ESTACION  ANIO  MES  DIA  HORA               FECHA  DIA_SEMANA AM_PM  \
# 0               6  2018    1    1     0 2018-01-01 00:00:00           2    AM
# 1               6  2018    1    1     1 2018-01-01 01:00:00           2    AM
# 2               6  2018    1    1     2 2018-01-01 02:00:00           2    AM
# 3               6  2018    1    1     3 2018-01-01 03:00:00           2    AM
# 4               6  2018    1    1     4 2018-01-01 04:00:00           2    AM
# ...           ...   ...  ...  ...   ...                 ...         ...   ...
# 3393835       198  2020    2   29    19 2020-02-29 19:00:00           7    PM
# 3393836       198  2020    2   29    20 2020-02-29 20:00:00           7    PM
# 3393837       198  2020    2   29    21 2020-02-29 21:00:00           7    PM
# 3393838       198  2020    2   29    22 2020-02-29 22:00:00           7    PM
# 3393839       198  2020    2   29    23 2020-02-29 23:00:00           7    PM
#
# ...

# %%
data_final_cierre.to_csv('../../data/DataFrame_Final_Cierre_FullFecha.csv', index=False)
