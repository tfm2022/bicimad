# %%
import pandas as pd

# %%
# MOVIMIENTOS

DF = pd.read_csv('../../data/DataFrame_Final_Cierre.csv', parse_dates=['FECHA'])

df_tracks=DF.copy()
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2082289 entries, 0 to 2082288
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ESTACION             int64
#  1   ANIO                 int64
#  2   MES                  int64
#  3   DIA                  int64
#  4   HORA                 int64
#  5   FECHA                datetime64[ns]
#  6   DIA_SEMANA           int64
#  7   AM_PM                object
#  8   TEMPORADA            object
#  9   Es_Festivo           int64
#  10  Es_FinSemana         int64
#  11  TEMPERATURA          float64
#  12  VIENTO               float64
#  13  PRESION              int64
#  14  HUMEDAD              int64
#  15  PRECIPITACION_1h     float64
#  16  PRECIPITACION_3h     float64
#  17  DESC_TIEMPO          object
#  18  DESC_TIEMPO_detalle  object
#  19  DEMANDA              int64
# dtypes: datetime64[ns](1), float64(4), int64(11), object(4)
# memory usage: 317.7+ MB

# %%
df_prediccion_ejemplo = df_tracks[(df_tracks['ANIO']==2020) & (df_tracks['MES']==2) & (df_tracks['DIA']<=7)]

# %%
df_prediccion_ejemplo
# Out:
#          ESTACION  ANIO  MES  DIA  HORA               FECHA  DIA_SEMANA AM_PM  \
# 1998880         1  2020    2    1     0 2020-02-01 00:00:00           7    AM
# 1998881         3  2020    2    1     0 2020-02-01 00:00:00           7    AM
# 1998882         4  2020    2    1     0 2020-02-01 00:00:00           7    AM
# 1998883         5  2020    2    1     0 2020-02-01 00:00:00           7    AM
# 1998884         6  2020    2    1     0 2020-02-01 00:00:00           7    AM
# ...           ...   ...  ...  ...   ...                 ...         ...   ...
# 2018864       178  2020    2    7    23 2020-02-07 23:00:00           6    PM
# 2018865       179  2020    2    7    23 2020-02-07 23:00:00           6    PM
# 2018866       192  2020    2    7    23 2020-02-07 23:00:00           6    PM
# 2018867       198  2020    2    7    23 2020-02-07 23:00:00           6    PM
# 2018868       199  2020    2    7    23 2020-02-07 23:00:00           6    PM
#
# ...

# %%
df_prediccion_ejemplo[['ESTACION', 'ANIO', 'MES', 'DIA', 'HORA', 'DEMANDA']].to_csv('../../data/SalidaPrediccionDiaria.csv', index=False)
